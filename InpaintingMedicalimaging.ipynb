# %% [markdown]
# #Install Accelerate Library

# %%
# !pip install accelerate

# %% [markdown]
# #Install Diffusers Library

# %%
pip install diffusers

# %% [markdown]
# #Install Transformers Library

# %%
pip install transformers

# %% [markdown]
# #Load Stable Diffusion Inpainting Pipeline

# %%
from diffusers import StableDiffusionInpaintPipeline
import torch
pipe = StableDiffusionInpaintPipeline.from_pretrained(
    "runwayml/stable-diffusion-inpainting",
    revision="fp16",
    torch_dtype=torch.float16,
).to('cuda')

# %%
print(pil_image1.size)

# %% [markdown]
# #Load and Display Images with PIL

# %%
from PIL import Image
import matplotlib.pyplot as plt
image1_path = '/content/orig1.jpg'
image2_path = '/content/mask1.jpg'
pil_image1 = Image.open(image1_path)
pil_image2 = Image.open(image2_path)

# %% [markdown]
# #Generate Inpainted Image with Custom Prompt

# %%
prompt = "Remove bump, Remove polyp, Remove Tumor, Clean Polyp, Clean Bump, No Polyp, No tumor, No bump"

image = pipe(prompt=prompt, image=pil_image1,  mask_image=pil_image2, guidance_scale =15,height = 640, width =640 , num_inference_steps = 20).images[0]
inpainted_image = image.convert(pil_image1.mode)
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
axs[0].imshow(pil_image1)
axs[0].set_title('Original Image')
axs[0].axis('off')
axs[1].imshow(inpainted_image)
axs[1].set_title('Inpainted Image')
axs[1].axis('off')
plt.show()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
image1_path = '/content/orig2.jpg'
image2_path = '/content/mask2.jpg'
pil_image1 = Image.open(image1_path)
pil_image2 = Image.open(image2_path)

# %%
prompt = "Remove bump, Remove polyp, Remove Tumor, Clean Polyp, Clean Bump, No Polyp, No tumor, No bump, Clean background"

image = pipe(prompt=prompt, image=pil_image1,  mask_image=pil_image2, guidance_scale =15,height = 640, width =640 , num_inference_steps = 30).images[0]

inpainted_image = image.convert(pil_image1.mode)
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
axs[0].imshow(pil_image1)
axs[0].set_title('Original Image')
axs[0].axis('off')
axs[1].imshow(inpainted_image)
axs[1].set_title('Inpainted Image')
axs[1].axis('off')
plt.show()
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
image1_path = '/content/orig3.jpg'
image2_path = '/content/mask3.jpg'
pil_image1 = Image.open(image1_path)
pil_image2 = Image.open(image2_path)

# %%
prompt = "Remove bump, Remove polyp, Remove Tumor, Clean Polyp, Clean Bump, No Polyp, No tumor, No bump, Clean background, Similar Background to surrounding"

image = pipe(prompt=prompt, image=pil_image1,  mask_image=pil_image2, guidance_scale =15,height = 640, width =640 , num_inference_steps = 15).images[0]
inpainted_image = image.convert(pil_image1.mode)
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
axs[0].imshow(pil_image1)
axs[0].set_title('Original Image')
axs[0].axis('off')
axs[1].imshow(inpainted_image)
axs[1].set_title('Inpainted Image')
axs[1].axis('off')
plt.show()
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
image1_path = '/content/orig4.jpg'
image2_path = '/content/mask4.jpg'
pil_image1 = Image.open(image1_path)
pil_image2 = Image.open(image2_path)

# %%
prompt = "Remove bump, Remove polyp, Remove Tumor, Clean Polyp, Clean Bump, No Polyp, No tumor, No bump, Clean background"

image = pipe(prompt=prompt, image=pil_image1,  mask_image=pil_image2, guidance_scale =15,height = 640, width =640 , num_inference_steps = 30).images[0]
inpainted_image = image.convert(pil_image1.mode)
fig, axs = plt.subplots(1, 2, figsize=(12, 6))
axs[0].imshow(pil_image1)
axs[0].set_title('Original Image')
axs[0].axis('off')  # Hide axis
axs[1].imshow(inpainted_image)
axs[1].set_title('Inpainted Image')
axs[1].axis('off')  # Hide axis
plt.show()
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
